# %% [markdown]
# # Foursquare API with Python-Jakarta

# %% [markdown]
# ## Introduction:
#
# In this project we will try to find an optimal location for a restaurant. Specifically, this report will be targeted to tourist who interested to try eat indonesian traditional food **Rumah Makan Padang** in **Jakarta**, Indonesia.

# %% [markdown]
# ### Import Libraries

# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Folium installed
# Libraries imported.

# %% [markdown]
# ### Define Foursquare Credentials and Version

# %% [markdown]
# On this My current account tier is Sandbox:
#
# 950 Regular Calls/Day
# 50 Premium Calls/Day
# 1 Photo per Venue
# 1 Tip per Venue
#
# So, i can't show you more than that!!!

# %% [markdown]
# ##### Input Client and secret id foursquare

# %%
CLIENT_ID = 'MTJLRYO0JNHRV5IF25XLSBVXX0ZEV4JL3LUZRIYBAZZ0BV5H' # your Foursquare ID
CLIENT_SECRET = 'JED1F3AQNICXCZTTIBEUIYT01BWY53JKYNS5MK5ZL4SUB1QC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: MTJLRYO0JNHRV5IF25XLSBVXX0ZEV4JL3LUZRIYBAZZ0BV5H
# CLIENT_SECRET:JED1F3AQNICXCZTTIBEUIYT01BWY53JKYNS5MK5ZL4SUB1QC

# %% [markdown]
# #### Let's assume that we are staying at the Kempinski hotel indonesia . So let's start by converting the Kempinski Hotel Indonesia address to its latitude and longitude coordinates.

# %%
address = 'Hotel Indonesia Kempinski Jakarta'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# -6.1952375 106.8221687

# %% [markdown]
# ### 1. Search for a specific venue category

# %% [markdown]
# #### Now, let's assume that it is lunch time, and you are craving indonesian traditional food. So, let's define a query to search for Indonesian traditional food that is within 500 metres from the Kempinski hotel.

# %%
search_query = 'Rumah Makan Padang'
radius = 500
print(search_query + ' .... OK!')
# Out:
# Rumah Makan Padang .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=MTJLRYO0JNHRV5IF25XLSBVXX0ZEV4JL3LUZRIYBAZZ0BV5H&client_secret=JED1F3AQNICXCZTTIBEUIYT01BWY53JKYNS5MK5ZL4SUB1QC&ll=-6.1952375,106.8221687&v=20180604&query=Rumah Makan Padang&radius=500&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebd622ded78b8001b14736b'},
#  'response': {'venues': [{'id': '4cdb9a46fc9737043f40d005',
#     'name': 'Rumah Makan Padang Sederhana',
#     'location': {'address': 'Jl. Raya Pasar Minggu',
#      'lat': -6.195343434826057,
#      'lng': 106.82147025850543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': -6.195343434826057,
#        'lng': 106.82147025850543}],
#      'distance': 78,
#      'cc': 'ID',
#      'city': 'Jakarta',
#      'state': 'Jakarta',
#      'country': 'Indonesia',
#      'formattedAddress': ['Jl. Raya Pasar Minggu',
#       'Jakarta',
#       'Jakarta',
#       'Indonesia']},
#     'categories': [{'id': '4deefc054765f83613cdba6f',
#       'name': 'Indonesian Restaurant',
#       'pluralName': 'Indonesian Restaurants',
#       'shortName': 'Indonesian',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/indonesian_',
#        'suffix': '.png'},
#       'primary': True}],
# ...

# %% [markdown]
# ##### Get relevant part of JSON and transform it into a *pandas* dataframe

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id  \
# 0  4cdb9a46fc9737043f40d005
# 1  5464b13a498eea2399eed5b1
# 2  51fa3900498e7a291adab159
# 3  52ac09ef498ee8beeb6fbb03
# 4  5211ab0211d2ef275f991226
#
#                                                 name  \
# 0                       Rumah Makan Padang Sederhana
# 1  Rumah Makan Padang Pinggir Kali Sebelah GRAND ...
# 2                          Rumah Makan Padang Sabana
# 3             Rumah Makan Padang Sasuai Kebon Kacang
# 4                    Rumah Makan Padang Bukit Tinggi
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4deefc054765f83613cdba6f', 'name': 'I...  v-1589469915    False
# 1                                                 []  v-1589469915    False
# 2                                                 []  v-1589469915    False
# 3                                                 []  v-1589469915    False
# 4                                                 []  v-1589469915    False
#
# ...

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered
# Out:
#                                                  name             categories  \
# 0                        Rumah Makan Padang Sederhana  Indonesian Restaurant
# 1   Rumah Makan Padang Pinggir Kali Sebelah GRAND ...                   None
# 2                           Rumah Makan Padang Sabana                   None
# 3              Rumah Makan Padang Sasuai Kebon Kacang                   None
# 4                     Rumah Makan Padang Bukit Tinggi                   None
# 5                                   Rumah makan cobex                   None
# 6                               Rumah makan boga sari                   None
# 7                Rumah makan sabana bundo sati juanda  Indonesian Restaurant
# 8                                  Rumah makan tabona       Asian Restaurant
# 9                                Rumah makan bu darti                   None
# 10                                Rumah Makan Sumenep  Indonesian Restaurant
# ...

# %% [markdown]
# ##### Let's visualize the Rumah padang restaurants that are nearby

# %%
dataframe_filtered.name
# Out:
# 0                          Rumah Makan Padang Sederhana
# 1     Rumah Makan Padang Pinggir Kali Sebelah GRAND ...
# 2                             Rumah Makan Padang Sabana
# 3                Rumah Makan Padang Sasuai Kebon Kacang
# 4                       Rumah Makan Padang Bukit Tinggi
# 5                                     Rumah makan cobex
# 6                                 Rumah makan boga sari
# 7                  Rumah makan sabana bundo sati juanda
# 8                                    Rumah makan tabona
# 9                                  Rumah makan bu darti
# 10                                  Rumah Makan Sumenep
# 11                                  Rumah makan ojolali
# 12                                   Rumah makan GARASI
# 13                            Rumah Makan Chaniago Jaya
# 14                                 Rumah makan tikungan
# 15                                 Rumah makan Bang Dul
# 16                  Rumah Makan Prasmanan Singgah Kudai
# ...

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Kempinski Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %% [markdown]
# ### 2. Explore a Given Venue

# %% [markdown]
# ##### A. Let's explore the closest indonesian traditional food,---- rumah makan padang

# %%
venue_id = '4cdb9a46fc9737043f40d005' # ID of Restaurant
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
url
# Out:
# 'https://api.foursquare.com/v2/venues/4cdb9a46fc9737043f40d005?client_id=MTJLRYO0JNHRV5IF25XLSBVXX0ZEV4JL3LUZRIYBAZZ0BV5H&client_secret=JED1F3AQNICXCZTTIBEUIYT01BWY53JKYNS5MK5ZL4SUB1QC&v=20180604'

# %%
result = requests.get(url).json()
print(result['response']['venue'].keys())
result['response']['venue']
# Out:
# dict_keys(['id', 'name', 'contact', 'location', 'canonicalUrl', 'categories', 'verified', 'stats', 'price', 'likes', 'dislike', 'ok', 'allowMenuUrlEdit', 'beenHere', 'specials', 'photos', 'reasons', 'hereNow', 'createdAt', 'tips', 'shortUrl', 'timeZone', 'listed', 'seasonalHours', 'pageUpdates', 'inbox', 'attributes'])
# {'id': '4cdb9a46fc9737043f40d005',
#  'name': 'Rumah Makan Padang Sederhana',
#  'contact': {},
#  'location': {'address': 'Jl. Raya Pasar Minggu',
#   'lat': -6.195343434826057,
#   'lng': 106.82147025850543,
#   'labeledLatLngs': [{'label': 'display',
#     'lat': -6.195343434826057,
#     'lng': 106.82147025850543}],
#   'cc': 'ID',
#   'city': 'Jakarta',
#   'state': 'Jakarta',
#   'country': 'Indonesia',
#   'formattedAddress': ['Jl. Raya Pasar Minggu',
#    'Jakarta',
#    'Jakarta',
#    'Indonesia']},
#  'canonicalUrl': 'https://foursquare.com/v/rumah-makan-padang-sederhana/4cdb9a46fc9737043f40d005',
#  'categories': [{'id': '4deefc054765f83613cdba6f',
# ...

# %% [markdown]
# ##### B. Get the venue's overall rating

# %%
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '57a31750498e312f898d0aaf' # ID resto 2
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# This venue has not been rated yet.

# %%
venue_id = '4c147b7da9c220a14dba579d' # ID of resto 3(restoran sederhana)
url = 'https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)

result = requests.get(url).json()
try:
    print(result['response']['venue']['rating'])
except:
    print('This venue has not been rated yet.')
# Out:
# 6.8

# %% [markdown]
# Since this restaurant has a slightly better rating, let's explore it further.

# %% [markdown]
# ##### C. Get the number of tips

# %%
result['response']['venue']['tips']['count']
# Out:
# 4

# %% [markdown]
# ##### D. Get the venue's tips

# %%
## RM Sederhana Tips
limit = 15 # set limit to be greater than or equal to the total number of tips
url = 'https://api.foursquare.com/v2/venues/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebd6d90b1cac0001df9031e'},
#  'response': {'tips': {'count': 4,
#    'items': [{'id': '4f7d7328e4b01b2a52a25947',
#      'createdAt': 1333621544,
#      'text': 'Sederhana plng enaakk,harga jelas..nasi putihnya sipp tenan..kalio ati ampla,sate rempelo,rendang Maknyusss..sate padange wajib Lep..jgn coba sederhana benhiL..ancurrr&MembLe....',
#      'type': 'user',
#      'canonicalUrl': 'https://foursquare.com/item/4f7d7328e4b01b2a52a25947',
#      'lang': 'id',
#      'likes': {'count': 0, 'groups': []},
#      'logView': True,
#      'agreeCount': 0,
#      'disagreeCount': 0,
#      'todo': {'count': 0},
#      'user': {'id': '9271722',
#       'firstName': 'OREO',
#       'photo': {'prefix': 'https://fastly.4sqi.net/img/user/',
#        'suffix': '/9271722_B916ociV_hVQS8Ym7dafvfxVYf5ZvVcJe_HWTyuUDK9mUpuWKNK9YYUkeNG8lstWyOMQhKVRV.jpg'}}}]}}}

# %%
tips = results['response']['tips']['items']

tip = results['response']['tips']['items'][0]
tip.keys()
# Out:
# dict_keys(['id', 'createdAt', 'text', 'type', 'canonicalUrl', 'lang', 'likes', 'logView', 'agreeCount', 'disagreeCount', 'todo', 'user'])

# %%
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips) # json normalize tips

# columns to keep
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id', 'user.firstName', 'user.lastName', 'user.gender', 'user.id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display tips
tips_filtered
# Out:
# C:\Users\User\Anaconda3\lib\site-packages\pandas\core\indexing.py:1418: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
#                                                                                                                                                                                  text  \
# 0  Sederhana plng enaakk,harga jelas..nasi putihnya sipp tenan..kalio ati ampla,sate rempelo,rendang Maknyusss..sate padange wajib Lep..jgn coba sederhana benhiL..ancurrr&MembLe....
#
#    agreeCount  disagreeCount                        id user.firstName  \
# 0  0           0              4f7d7328e4b01b2a52a25947  OREO
#
#    user.lastName  user.gender  user.id
# 0 NaN            NaN           9271722

# %% [markdown]
# Now remember that because we are using a personal developer account, then we can access only 2 of the restaurant's tips, instead of all 15 tips.

# %% [markdown]
# #### Get User's tips

# %%
# define tips URL
url = 'https://api.foursquare.com/v2/users/{}/tips?client_id={}&client_secret={}&v={}&limit={}'.format(user_id, CLIENT_ID, CLIENT_SECRET, VERSION, limit)

# send GET request and get user's tips
results = requests.get(url).json()
tips = results['response']['tips']['items']

# format column width
pd.set_option('display.max_colwidth', -1)

tips_df = json_normalize(tips)

# filter columns
filtered_columns = ['text', 'agreeCount', 'disagreeCount', 'id']
tips_filtered = tips_df.loc[:, filtered_columns]

# display user's tips
tips_filtered
# Out:
#                                                                                                                                     text  \
# 0   Langsung Ceria happy pas 5 Berger King dateng by Gofood🍔🍔🍔🍔🍔
# 1   Ngambek ga dapet CARL’s Jr🍔🍔🍟🍟🍗🍗Pesen Hokben tutup jga😭😭Gantenge Mas Marko mpe lehernya ambless❤️❤️
# 2   Ksukaan Marko❤️Endru
# 3   Nyamm Nyamm ksukaan Anak2😻😻
# 4   CEMPEDAK MATENG FROM PARUNG😭😭😻😻😻Ndutttttt
# 5   Mendung enak nya Bubu ahhh❤️Oreo Jagoanku yg Penyendiri ga mau campur ma cewek2 di blakang
# 6   Nenen duyu ahh😻😻Momo emak yg Sayang anak❤️
# 7   New Unit FraserPark❤️💙Rumah Unyu2 100 meter Rumah tumbuh lucu Sayang abang Bakso ma Cilok lom ada
# 8   Mba Bubur Keceh Badai😀Dagangannya cantik bikin kami naksir beli
# 9   Paporit selamanya😃😃Ketupat ketan legitttt
# 10  Lamang Tapainya pulenn legittt👍👍50 rbu sepasang dengan tapai hitam.Colek sama Rendang Paru
# ...

# %%
tip_id = '5eba9a208d63ef000777d72a' # tip id

# define URL
url = 'http://api.foursquare.com/v2/tips/{}?client_id={}&client_secret={}&v={}'.format(tip_id, CLIENT_ID, CLIENT_SECRET, VERSION)

# send GET Request and examine results
result = requests.get(url).json()
print(result['response']['tip']['venue']['name'])
print(result['response']['tip']['venue']['location'])
# Out:
# Hari Hari Pasar Swalayan
# {'address': 'CBD Bintaro Jaya Sektor 7, Blok B7/B2 No. 1', 'crossStreet': 'Jl. M.H. Thamrin', 'lat': -6.278023157670253, 'lng': 106.7239684608349, 'labeledLatLngs': [{'label': 'display', 'lat': -6.278023157670253, 'lng': 106.7239684608349}], 'cc': 'ID', 'city': 'Tangerang', 'state': 'Banten', 'country': 'Indonesia', 'formattedAddress': ['CBD Bintaro Jaya Sektor 7, Blok B7/B2 No. 1 (Jl. M.H. Thamrin)', 'Tangerang', 'Banten', 'Indonesia']}

# %% [markdown]
# ### 3. Explore a location

# %%
latitude = -6.1952375 
longitude = 106.8221687

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/explore?client_id=MTJLRYO0JNHRV5IF25XLSBVXX0ZEV4JL3LUZRIYBAZZ0BV5H&client_secret=JED1F3AQNICXCZTTIBEUIYT01BWY53JKYNS5MK5ZL4SUB1QC&ll=-6.1952375,106.8221687&v=20180604&radius=500&limit=30'

# %%
import requests

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


# add Ecco as a red circle mark
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    popup='Ecco',
    fill=True,
    color='red',
    fill_color='red',
    fill_opacity=0.6
    ).add_to(venues_map)


# add popular spots to the map as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        popup=label,
        fill=True,
        color='blue',
        fill_color='blue',
        fill_opacity=0.6
        ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# define URL
url = 'https://api.foursquare.com/v2/venues/trending?client_id={}&client_secret={}&ll={},{}&v={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION)

# send GET request and get trending venues
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ebd697bdf2774001bc5a27e'},
#  'response': {'venues': []}}

# %%
if len(results['response']['venues']) == 0:
    trending_venues_df = 'No trending venues are available at the moment!'
    
else:
    trending_venues = results['response']['venues']
    trending_venues_df = json_normalize(trending_venues)

    # filter columns
    columns_filtered = ['name', 'categories'] + ['location.distance', 'location.city', 'location.postalCode', 'location.state', 'location.country', 'location.lat', 'location.lng']
    trending_venues_df = trending_venues_df.loc[:, columns_filtered]

    # filter the category for each row
    trending_venues_df['categories'] = trending_venues_df.apply(get_category_type, axis=1)

# %%
# display trending venues
trending_venues_df
# Out:
# 'No trending venues are available at the moment!'

# %%
if len(results['response']['venues']) == 0:
    venues_map = 'Cannot generate visual as no trending venues are available at the moment!'

else:
    venues_map = folium.Map(location=[latitude, longitude], zoom_start=15) # generate map centred around Ecco


    # add Ecco as a red circle mark
    folium.features.CircleMarker(
        [latitude, longitude],
        radius=10,
        popup='Kempinski Hotel',
        fill=True,
        color='red',
        fill_color='red',
        fill_opacity=0.6
    ).add_to(venues_map)


    # add the trending venues as blue circle markers
    for lat, lng, label in zip(trending_venues_df['location.lat'], trending_venues_df['location.lng'], trending_venues_df['name']):
        folium.features.CircleMarker(
            [lat, lng],
            radius=5,
            poup=label,
            fill=True,
            color='blue',
            fill_color='blue',
            fill_opacity=0.6
        ).add_to(venues_map)

# %%
# display map
venues_map
# Out:
# 'Cannot generate visual as no trending venues are available at the moment!'

# %% [markdown]
# #### References  and Sources
# Alex Aklson, Coursera, cognitive class and IBM
